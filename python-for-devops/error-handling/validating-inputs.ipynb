# %% [markdown]
# # Validating Inputs for Flexible Resource Tagger
#
# ## Exercise: Validating Inputs for Flexible Resource Tagger
#
# The `manage_tags` function we implemented in the Python Fundamentals section is powerful, but it assumes the first argument is always a dictionary. In a real system, inputs can be unpredictable. You need to harden the function to make it production-ready by adding validation that rejects invalid inputs immediately.
#
# ## Problem Description
#
# Your task is to take the working `manage_tags` function and add input validation. This exercise builds directly on your solution from the Python Fundamentals section.
#
# ## Behavioral Requirements
#
# Modify `manage_tags`:
#
# - Add validation at the beginning of the function.
# - It must raise a `TypeError` if the `existing_tags` argument is not a dictionary.
# - Make sure to provide a descriptive error message.
# - The core logic for processing tags remains the same.
#
# ## How Your Solution Will Be Tested
#
# The tests for this part run both the previous test suite, and add more test cases for the new validation logic:
#
# - We will call `manage_tags` with various invalid first arguments (a string, a list, `None`).
# - For each invalid call, the tests will assert that a `TypeError` is raised.

# %%
def manage_tags(existing_tags: dict, *simple_tags, **key_value_tags) -> dict:
    """
    Applies simple and key-value tags to an existing dictionary of tags.

    Args:
        existing_tags: The initial dictionary of tags.
        *simple_tags: Positional string arguments to be added as tags with a
                      value of 'true'. Duplicates are ignored.
        **key_value_tags: Keyword arguments to be added or used to overwrite
                          existing tags.

    Returns:
        A new dictionary with all tags merged.

    Raises:
        TypeError: If existing_tags is not a dictionary.
    """
    # TODO: Add validation here.
    if not isinstance(existing_tags, dict):
        raise TypeError("existing_tags must be a dictionary.")


    # --- Core logic from previous part (no changes needed below) ---
    new_tags = existing_tags.copy()

    for tag in set(simple_tags):
        new_tags[tag] = 'true'

    new_tags = new_tags | key_value_tags

    return new_tags
