# %% [markdown]
# # Validating Inputs for Object-Oriented Deployment Manager
#
# Our previously implemented `Deployment` class from works, but it's brittle: it blindly trusts its inputs. Now, as a senior DevOps engineer, you need to harden the class to make it production-ready. This means adding robust validation so that it fails fast and loudly when used incorrectly.
#
# ## Problem Description
#
# Your task is to take the working `Deployment` class and add input validation using exception handling. You will modify the `__init__` and `deploy` methods.
#
# ## Behavioral Requirements
#
# This exercise builds upon the class from the Object-Oriented Deployment Manager exercise in the Python Fundamentals section. You will start with a working implementation of the core logic.
#
# Modify `__init__(self, service_name, environment)`:
#
# - Add validation at the beginning of the method.
# - It must raise a `TypeError` if `service_name` or `environment` are not strings.
# - It must raise a `ValueError` if `service_name` or `environment` are empty strings.
# - Make sure to provide a descriptive error message.
#
# Modify `deploy(self, new_version)`:
#
# - Add validation at the beginning of the method.
# - It must raise a `TypeError` if `new_version` is not a string.
# - It must raise a `ValueError` if `new_version` is an empty string.
# - Make sure to provide a descriptive error message.
#
# The behavior of `rollback` and `check_status` remains the same.
#
# ## How Your Solution Will Be Tested
#
# The tests for this part focus exclusively on the new validation logic:
#
# - **Invalid Initialization:** We will attempt to create a `Deployment` object with various invalid inputs (empty strings, `None`, non-string types) and assert that a `TypeError` or `ValueError` are raised under the correct circumstances.
# - **Invalid Deployment:** We will call the `deploy` method on a valid object but with an invalid `new_version` and assert that a `TypeError` or `ValueError` are raised under the correct circumstances.

# %%
class Deployment:
    """
    Manages the state and version history of a software deployment.
    """

    def __init__(self, service_name: str, environment: str):
        """
        Initializes a new Deployment instance.
        """
        # TODO: Add validation here.

        if not isinstance(service_name, str) or not isinstance(environment, str):
            raise TypeError('Service name and environment must be strings.')

        if not service_name or not environment:
            raise ValueError('Service name and environment cannot be empty strings.')

        self.service_name = service_name
        self.environment = environment
        self.status = 'pending'
        self._history = []

    def deploy(self, new_version: str):
        """
        Deploys a new version by adding it to the history.
        """
        # TODO: Add validation here.
        if not isinstance(new_version, str):
            raise TypeError('New version must be a string.')

        if not new_version:
            raise ValueError('New version cannot be an empty string.')
        
        self._history.append(new_version)
        self.status = 'deployed'

    def rollback(self) -> bool:
        """
        Rolls back to the previous version by removing the current one from history.
        """
        if len(self._history) < 2:
            return False

        self._history.pop()
        self.status = 'rolled_back'
        return True

    def check_status(self) -> dict:
        """
        Returns a dictionary representing the current state of the deployment.
        """
        current_version = self._history[-1] if self._history else None
        return {
            'service_name': self.service_name,
            'environment': self.environment,
            'version': current_version,
            'status': self.status,
        }
